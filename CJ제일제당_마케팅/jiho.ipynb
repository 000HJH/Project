# %%
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn.objects as so

# %%
#엑셀파일 시트 5개를 통합
all_lst =pd.read_excel('data/11번가_장바구니.xlsx',sheet_name=0)
for i in range(1,5):
    i_lst = pd.read_excel('data/11번가_장바구니.xlsx',sheet_name=i)
    all_lst = all_lst.append(i_lst, ignore_index=True)

all_lst
# Out:
# C:\Users\000hj\AppData\Local\Temp\ipykernel_23492\2835411247.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_lst = all_lst.append(i_lst, ignore_index=True)
# C:\Users\000hj\AppData\Local\Temp\ipykernel_23492\2835411247.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_lst = all_lst.append(i_lst, ignore_index=True)
# C:\Users\000hj\AppData\Local\Temp\ipykernel_23492\2835411247.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_lst = all_lst.append(i_lst, ignore_index=True)
# C:\Users\000hj\AppData\Local\Temp\ipykernel_23492\2835411247.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# xlsx -> csv저장
all_lst.to_csv('data/11번가_장바구니.csv', encoding='UTF-8')

# %%
df = pd.read_csv('data/11번가_장바구니.csv')
df =df.iloc[:,1:]
df
# Out:
#                  자사주문번호              거래처       주문일 사은품여부     출고예정일 주문/배송상태  \
# 0     40787430531512147  외부몰_직거래_11번가(신)  20230531     N  20230602   배송 완료
# 1     40787430531510211  외부몰_직거래_11번가(신)  20230531     N  20230602   배송 완료
# 2     40787430531510193  외부몰_직거래_11번가(신)  20230531     N  20230602   배송 완료
# 3     40787430531510193  외부몰_직거래_11번가(신)  20230531     N  20230602   배송 완료
# 4     40787430531510193  외부몰_직거래_11번가(신)  20230531     N  20230602   배송 완료
# ...                 ...              ...       ...   ...       ...     ...
# 1543  40787430501948661  외부몰_직거래_11번가(신)  20230501     N  20230502   배송 완료
# 1544  40787430501948661  외부몰_직거래_11번가(신)  20230501     N  20230502   배송 완료
# 1545  40787430501948661  외부몰_직거래_11번가(신)  20230501     N  20230502   배송 완료
# 1546  40787430501948661  외부몰_직거래_11번가(신)  20230501     N  20230502   배송 완료
# 1547  40787430501948651  외부몰_직거래_11번가(신)  20230501     N  20230502   배송 완료
#
# ...

# %%
df1 = df[['자사주문번호','상품명','주문수량']]
df1
# Out:
#                  자사주문번호                                               상품명  \
# 0     40787430531512147                          오천년의 신비 명품천일염(굵은입자) 10kg
# 1     40787430531510211                          오천년의 신비 명품천일염(굵은입자) 10kg
# 2     40787430531510193                                    한입쏙 비엔나 120Gx2
# 3     40787430531510193                          [11번가] 고메 함박스테이크 152Gx5개
# 4     40787430531510193                          [11번가] 고메 함박스테이크 152Gx5개
# ...                 ...                                               ...
# 1543  40787430501948661  [복합_마켓전략]주먹밥세트(소고기버섯+불닭마요+갈릭마요+치즈닭갈비+김치치즈+버터장조림)
# 1544  40787430501948661  [복합_마켓전략]주먹밥세트(소고기버섯+불닭마요+갈릭마요+치즈닭갈비+김치치즈+버터장조림)
# 1545  40787430501948661  [복합_마켓전략]주먹밥세트(소고기버섯+불닭마요+갈릭마요+치즈닭갈비+김치치즈+버터장조림)
# 1546  40787430501948661  [복합_마켓전략]주먹밥세트(소고기버섯+불닭마요+갈릭마요+치즈닭갈비+김치치즈+버터장조림)
# 1547  40787430501948651                         [11번가] 다담 안동찜닭 양념 220gX6개
#
#       주문수량
# 0        1
# 1        1
# 2        2
# 3        5
# 4        5
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 3
#       1 #df1.pivot(index='자사주문번호',columns='상품명', values='주문수량')
#       2 df2 = df1.set_index('자사주문번호').stack()
# ----> 3 df2.unstack()
#
# File c:\Users\000hj\anaconda3\lib\site-packages\pandas\core\series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
#    (...)
#    4153 b    2    4
#    4154 """
#    4155 from pandas.core.reshape.reshape import unstack
# -> 4157 return unstack(self, level, fill_value)
#
# File c:\Users\000hj\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:491, in unstack(obj, level, fill_value)
#     489 if is_1d_only_ea_dtype(obj.dtype):
#     490     return _unstack_extension_series(obj, level, fill_value)
# --> 491 unstacker = _Unstacker(
# ...
